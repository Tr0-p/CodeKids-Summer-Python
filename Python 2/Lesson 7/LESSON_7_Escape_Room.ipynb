# %% [markdown]
# # PYTHON 2 - LESSON 7
# ## Functions (Escape the Room Game)
#
# Date: 11 June 2024
#
# Here is a map of our Escape the Room Game: https://drive.google.com/file/d/17cOwUhIpsx0UJ0aWbWC0l2iMB8Qt16wf/view?usp=share_link

# %%
# Define a function to ask the player to choose a door
def choose_door(floor_description):
  return input(f"You are on the {floor_description}. Choose a door: ").strip()


### FLOOR 1 ###
# Handles the doors on the first floor.
def floor_one(inventory, hearts):
  print("\nFloor 1: You see three doors labeled A, B, C.")
  choice = choose_door("first floor")  # Asks player to choose a door on the first floor.
  status = None

  # Things that happen depending on which door the player chooses.
  if choice.upper() == "A":
    print("You found a rusty key!")
    inventory.append("rusty key")  # Add a rusty key to the inventory.

  elif choice.upper() == "B":
    if "rusty key" in inventory:
      print("You opened the door with a rusty key!")
      print("You found a staircase!")
      status = "next floor"  # Update status to move to the next floor.
    else:
      print("This door is locked. You need a rusty key.")

  elif choice.upper() == "C":
    print("You found a trap door and fell into a pit. Start over!")
    hearts -= 1  # Decrease hearts by 1.
    status = "start over"  # Update status to start over.

  else:
    print(f"Door {choice} doesn't exist!")

  return inventory, hearts, status


### FLOOR 2 ###
# Handles the doors on the second floor.
def floor_two(inventory, hearts):
  print("\nFloor 2: You see three doors colored blue, red, green.")
  choice = choose_door("second floor")

  # This section needs to be implemented for floor two door choices.

  return inventory, hearts, status


### FLOOR 3 ###
# Handles the doors on the third floor.
def floor_three(inventory, hearts):
  print("\nFloor 3: You see doors numbered 1, 2, 3.")
  choice = choose_door("third floor")

  # This section needs to be implemented for floor three door choices.

  return inventory, hearts, status


### MOVE FLOORS ###
# Determines the new floor based on the 'game status'
# This section needs to be implemented still

def move_player(current_floor, status):
  if status == 'next_floor':
    new_floor = ''
  elif status == 'start_over':
    new_floor = ''
  else:
    new_floor = ''

  return new_floor


### GAME START ###
# Starts the game and initializes game state.
def play_game():
  print("Welcome to my escape the house game!")
  print("You are standing at the entrance of a mysterious building with many floors. Your goal is to escape.")
  name = input("Enter your name: ")  # Prompts player to enter their name.
  print(f"Good luck, {name}!")

  inventory = []  # List to keep track of items player collects.
  current_floor = 1  # Tracks the current floor player is on.
  hearts = 2  # Tracks the number of hearts/lives the player has.

  while hearts > 0:  # Game continues as long as player has hearts.
    print(f"\n{name}, you have {hearts} hearts remaining.")

    # Floor logic based on current floor number.
    if current_floor == 1:
      inventory, hearts, status = floor_one(inventory, hearts)  # first floor

play_game()  # Start the game by calling the play_game function.
# Out:
# Welcome to my escape the house game!
# You are standing at the entrance of a mysterious building with many floors. Your goal is to escape.
# Enter your name: Magdalena
# Good luck, Magdalena!
#
# Magdalena, you have 2 hearts remaining.
#
# Floor 1: You see three doors labeled A, B, C.
# You are on the first floor. Choose a door: A
# You found a rusty key!
#
# Magdalena, you have 2 hearts remaining.
#
# Floor 1: You see three doors labeled A, B, C.
# You are on the first floor. Choose a door: B
# You opened the door with a rusty key!
# You found a staircase!
#
# Magdalena, you have 2 hearts remaining.
#
# Floor 1: You see three doors labeled A, B, C.
# You are on the first floor. Choose a door: C
# You found a trap door and fell into a pit. Start over!
#
# Magdalena, you have 1 hearts remaining.
#
# Floor 1: You see three doors labeled A, B, C.
# You are on the first floor. Choose a door: C
# You found a trap door and fell into a pit. Start over!
